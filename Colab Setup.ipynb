# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# # Welcome to Python

# %%
import spacy

# %%
print(spacy.__version__)
# Out:
# 2.2.4

# %%
import nltk

# %%
print(nltk.__version__)
# Out:
# 3.2.5

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
