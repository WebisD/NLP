# %% [markdown]
# # Recurrent Neural Network

# %% [markdown]
# The neurons are able to send feedback signals to each other

# %% [markdown]
# RNN has a *memory*, wich remebers all the information about what has been calculated

# %% [markdown]
# RNN allows us to operate over vector sequences: Sequences in input, output, or in both

# %% [markdown]
# ## Vanishing gradient problem

# %% [markdown]
# Problem in the first layers that can affect all the others

# %% [markdown]
# Use ReLU instad of Sigmoid or Tanh's activation function

# %% [markdown]
# ## LSTM and GRU

# %% [markdown]
# Long Short Term Memory
#
# Generated recurrent unity

# %% [markdown]
# RNN has short term, so, if a sequence is long enough, the RNN will have a hard time to carry information from earlier time steps to later ones

# %% [markdown]
# In a paragraph the RNN may leave out important information from the beginning

# %% [markdown]
# Thats why they created LSTM and GRU

# %% [markdown]
# They have *gates* that can regulate the flow information

# %% [markdown]
# This gates can control what information is usefull and what is not
