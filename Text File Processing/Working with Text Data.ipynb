# %% [markdown]
# # 1) Working with Text Data

# %% [markdown]
# ## Prints Formats

# %%
name = 'Ankit'

# %%
print(name)
# Out:
# Ankit

# %%
print('My name is {}'.format(name))
# Out:
# My name is Ankit

# %%
print(f'My name is {name}')
# Out:
# My name is Ankit

# %% [markdown]
# ## Allingment in print

# %%
# create a list of tuples
marvel = [('Film', 'U.S. release date',	'Director(s)'),
          ('Iron Man',	'May 2, 2008', 'Jon Favreau'),
          ('The Incredible Hulk', 'June 13, 2008', 'Louis Leterrier'),
          ('Thor', 'May 6, 2011', 'Kenneth Branagh'),
          ('Captain America: The First Avenger', 'July 22, 2011',	'Joe Johnston'),]

# %%
for film in marvel:
  print(film)
# Out:
# ('Film', 'U.S. release date', 'Director(s)')
# ('Iron Man', 'May 2, 2008', 'Jon Favreau')
# ('The Incredible Hulk', 'June 13, 2008', 'Louis Leterrier')
# ('Thor', 'May 6, 2011', 'Kenneth Branagh')
# ('Captain America: The First Avenger', 'July 22, 2011', 'Joe Johnston')

# %%
for film in marvel:
  print(f'{film[0]:{40}}, {film[1]:{20}}, {film[2]:{20}}')
# Out:
# Film                                    , U.S. release date   , Director(s)
# Iron Man                                , May 2, 2008         , Jon Favreau
# The Incredible Hulk                     , June 13, 2008       , Louis Leterrier
# Thor                                    , May 6, 2011         , Kenneth Branagh
# Captain America: The First Avenger      , July 22, 2011       , Joe Johnston

# %%
# > right allingmnet
# ^ center allingment
# < left allingment (DEFAULT)
for film in marvel:
  print(f'{film[0]:>{40}}, {film[1]:^{20}}, {film[2]:.>{20}}')
# Out:
#                                     Film,  U.S. release date  , .........Director(s)
#                                 Iron Man,     May 2, 2008     , .........Jon Favreau
#                      The Incredible Hulk,    June 13, 2008    , .....Louis Leterrier
#                                     Thor,     May 6, 2011     , .....Kenneth Branagh
#       Captain America: The First Avenger,    July 22, 2011    , ........Joe Johnston

# %% [markdown]
# # 2) Working with .csv and .tsv files

# %% [markdown]
# ### Reading

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/NLP/Text File Processing/moviereviews.tsv', sep='\t')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#   label                                             review
# 0   neg  how do films like mouse hunt get into theatres...
# 1   neg  some talented actresses are blessed with a dem...
# 2   pos  this has been an extraordinary year for austra...
# 3   pos  according to hollywood movies made in last few...
# 4   neg  my first press screening of 1998 and already i...

# %%
data.shape
# Out:
# (2000, 2)

# %%
pos = data[data['label'] == 'pos']

# %%
pos.head()
# Out:
#    label                                             review
# 2    pos  this has been an extraordinary year for austra...
# 3    pos  according to hollywood movies made in last few...
# 11   pos  with stars like sigourney weaver ( " alien " t...
# 16   pos  i remember hearing about this film when it fir...
# 18   pos  garry shandling makes his long overdue starrin...

# %% [markdown]
# ### Writing

# %%
pos.to_csv('/content/drive/MyDrive/Colab Notebooks/NLP/Text File Processing/pos.csv', sep='\t')

# %%
# Ao salvar, ele salva a coluna 0,1,2,3...
data1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/NLP/Text File Processing/pos.csv', sep='\t')

# %%
data1
# Out:
#      Unnamed: 0 label                                             review
# 0             2   pos  this has been an extraordinary year for austra...
# 1             3   pos  according to hollywood movies made in last few...
# 2            11   pos  with stars like sigourney weaver ( " alien " t...
# 3            16   pos  i remember hearing about this film when it fir...
# 4            18   pos  garry shandling makes his long overdue starrin...
# ..          ...   ...                                                ...
# 995        1995   pos  i like movies with albert brooks , and i reall...
# 996        1996   pos  it might surprise some to know that joel and e...
# 997        1997   pos  the verdict : spine-chilling drama from horror...
# 998        1998   pos  i want to correct what i wrote in a former ret...
# 999        1999   pos  a couple of months ago , when i first download...
#
# [1000 rows x 3 columns]

# %%
data1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/NLP/Text File Processing/pos.csv', sep='\t', index_col=0)
data1
# Out:
#      label                                             review
# 2      pos  this has been an extraordinary year for austra...
# 3      pos  according to hollywood movies made in last few...
# 11     pos  with stars like sigourney weaver ( " alien " t...
# 16     pos  i remember hearing about this film when it fir...
# 18     pos  garry shandling makes his long overdue starrin...
# ...    ...                                                ...
# 1995   pos  i like movies with albert brooks , and i reall...
# 1996   pos  it might surprise some to know that joel and e...
# 1997   pos  the verdict : spine-chilling drama from horror...
# 1998   pos  i want to correct what i wrote in a former ret...
# 1999   pos  a couple of months ago , when i first download...
#
# [1000 rows x 2 columns]

# %% [markdown]
# # 3) Create files without libraries

# %% [markdown]
# ## Reading

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/NLP/Text File Processing/
# Out:
# /content/drive/MyDrive/Colab Notebooks/NLP/Text File Processing

# %%
# %%writefile test1.txt
# Hello, this is a test file
# First Line
# 42
# Third one
# Out:
# Overwriting test1.txt

# %%
# %%writefile -a test1.txt
# Added in append mode
# Out:
# Appending to test1.txt

# %%
file = open('test1.txt', mode='r')

# %%
file
# Out:
# <_io.TextIOWrapper name='test1.txt' mode='r' encoding='UTF-8'>

# %%
file.read()
# Out:
# 'Hello, this is a test file\nFirst Line\n42\nThird oneAdded in append mode'

# %%
file.read()
# reached the end of the file after read
# Out:
# ''

# %%
file.seek(0) # change cursor position
# Out:
# 0

# %%
file.read()
# Out:
# 'Hello, this is a test file\nFirst Line\n42\nThird oneAdded in append mode'

# %%
file.seek(1)
# Out:
# 1

# %%
file.read()
# Out:
# 'First Line\n42\nThird oneAdded in append mode'

# %%
file.seek(0)
# Out:
# 0

# %%
file.readlines()
# Out:
# ['Hello, this is a test file\n',
#  'First Line\n',
#  '42\n',
#  'Third oneAdded in append mode']

# %%
file.seek(0)
# Out:
# 0

# %%
file.readline() # read line by line
# Out:
# 'Hello, this is a test file\n'

# %%
file.readline()
# Out:
# 'First Line\n'

# %%
file.readline()
# Out:
# '42\n'

# %%
file.readline()
# Out:
# 'Third oneAdded in append mode'

# %%
file.readline() # finish lines
# Out:
# ''

# %%
file.closed
# Out:
# False

# %%
file.close()

# %%
file.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-f3fc120c03c1> in <module>()
# ----> 1 file.read()
#
# ValueError: I/O operation on closed file.

# %%
with open('test1.txt', 'r') as file: # automatically close the file when finished
  print(file.read())
# Out:
# Hello, this is a test file
# First Line
# 42
# Third oneAdded in append mode

# %%
with open('test1.txt', 'r') as file:
  print(file.read().strip())
# Out:
# Hello, this is a test file
# First Line
# 42
# Third oneAdded in append mode

# %% [markdown]
# ## Writing

# %%
file = open('test2.txt', 'w')

# %%
file.write('I am writing this file from a python')
# Out:
# 36

# %%
file.close() # close to finish write

# %%
with open('test3.txt', 'w') as file: # No need to close
  file.write('File writing in with Block')
